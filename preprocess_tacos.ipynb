# %%
import pandas as pd
import numpy as np
import imageio

# %%
columns_name =  ['sentence_id','sentence','video','start_frame','end_frame','vegetable','annotated_end']

tacos_data = pd.read_csv("./tacos.csv", names = columns_name ,header = None)

# %% [markdown]
# tacos_data.head()

# %%
tacos_data.head()
# Out:
#    sentence_id                   sentence    video  start_frame  end_frame  \
# 0  s13-d21_1_1  He took out cutting board  s13-d21          252        452
# 1  s13-d21_1_2          He took out knife  s13-d21          471        627
# 2  s13-d21_1_3       He took out cucumber  s13-d21          627        975
# 3  s13-d21_1_4          He took out plate  s13-d21         1004       1353
# 4  s13-d21_1_5         He washed cucumber  s13-d21         1366       1594
#
#   vegetable  annotated_end
# 0  cucumber            437
# 1  cucumber            637
# 2  cucumber            979
# 3  cucumber           1320
# 4  cucumber           1632

# %%
tacos_data.pop('annotated_end')
# Out:
# 0          437
# 1          637
# 2          979
# 3         1320
# 4         1632
#          ...
# 18222    11196
# 18223    12074
# 18224    12390
# 18225    12826
# 18226    13664
# Name: annotated_end, Length: 18227, dtype: int64

# %%
tacos_data.pop('vegetable')
# Out:
# 0         cucumber
# 1         cucumber
# 2         cucumber
# 3         cucumber
# 4         cucumber
#            ...
# 18222    pineapple
# 18223    pineapple
# 18224    pineapple
# 18225    pineapple
# 18226    pineapple
# Name: vegetable, Length: 18227, dtype: object

# %%
tacos_data.head()
# Out:
#    sentence_id                   sentence    video  start_frame  end_frame
# 0  s13-d21_1_1  He took out cutting board  s13-d21          252        452
# 1  s13-d21_1_2          He took out knife  s13-d21          471        627
# 2  s13-d21_1_3       He took out cucumber  s13-d21          627        975
# 3  s13-d21_1_4          He took out plate  s13-d21         1004       1353
# 4  s13-d21_1_5         He washed cucumber  s13-d21         1366       1594

# %% [markdown]
# # Add processed video name

# %%
tacos_data['Video_path']=tacos_data.apply(lambda row: row['video']+'.avi',axis=1)

# %%
tacos_data.head()
# Out:
#    sentence_id                   sentence    video  start_frame  end_frame  \
# 0  s13-d21_1_1  He took out cutting board  s13-d21          252        452
# 1  s13-d21_1_2          He took out knife  s13-d21          471        627
# 2  s13-d21_1_3       He took out cucumber  s13-d21          627        975
# 3  s13-d21_1_4          He took out plate  s13-d21         1004       1353
# 4  s13-d21_1_5         He washed cucumber  s13-d21         1366       1594
#
#     Video_path
# 0  s13-d21.avi
# 1  s13-d21.avi
# 2  s13-d21.avi
# 3  s13-d21.avi
# 4  s13-d21.avi

# %% [markdown]
# # The number of descriptions for each video

# %%
tacos_data.dropna(axis=1,inplace=True,how='all')
cols=list(tacos_data.columns)
cols.append('CaptionNums')
tacos_data=pd.merge(tacos_data,tacos_data.groupby('video').count().iloc[:,0],on='video',how='left')
tacos_data.columns=pd.Index(cols)

# %%
tacos_data.head()
# Out:
#    sentence_id                   sentence    video  start_frame  end_frame  \
# 0  s13-d21_1_1  He took out cutting board  s13-d21          252        452
# 1  s13-d21_1_2          He took out knife  s13-d21          471        627
# 2  s13-d21_1_3       He took out cucumber  s13-d21          627        975
# 3  s13-d21_1_4          He took out plate  s13-d21         1004       1353
# 4  s13-d21_1_5         He washed cucumber  s13-d21         1366       1594
#
#     Video_path  CaptionNums
# 0  s13-d21.avi          112
# 1  s13-d21.avi          112
# 2  s13-d21.avi          112
# 3  s13-d21.avi          112
# 4  s13-d21.avi          112

# %% [markdown]
# # Check whether there is NULL entry

# %%
tacos_data.isnull().any()
# Out:
# sentence_id    False
# sentence       False
# video          False
# start_frame    False
# end_frame      False
# Video_path     False
# CaptionNums    False
# dtype: bool

# %% [markdown]
# # Putting video address

# %%
video_path = "./data/videos"

# %%
import os

# %%
tacos_data['Video_path']=tacos_data['Video_path'].apply(lambda x: video_path+"/"+x)

# %%
tacos_data.head()
# Out:
#    sentence_id                   sentence    video  start_frame  end_frame  \
# 0  s13-d21_1_1  He took out cutting board  s13-d21          252        452
# 1  s13-d21_1_2          He took out knife  s13-d21          471        627
# 2  s13-d21_1_3       He took out cucumber  s13-d21          627        975
# 3  s13-d21_1_4          He took out plate  s13-d21         1004       1353
# 4  s13-d21_1_5         He washed cucumber  s13-d21         1366       1594
#
#                   Video_path  CaptionNums
# 0  ./data/videos/s13-d21.avi          112
# 1  ./data/videos/s13-d21.avi          112
# 2  ./data/videos/s13-d21.avi          112
# 3  ./data/videos/s13-d21.avi          112
# 4  ./data/videos/s13-d21.avi          112

# %%
len(tacos_data['video'].unique())
# Out:
# 127

# %% [markdown]
# # Check if video exists

# %%
tacos_data['exists']=tacos_data['Video_path'].apply(lambda x: os.path.exists(x))
tacos_data.head()
# Out:
#    sentence_id                   sentence    video  start_frame  end_frame  \
# 0  s13-d21_1_1  He took out cutting board  s13-d21          252        452
# 1  s13-d21_1_2          He took out knife  s13-d21          471        627
# 2  s13-d21_1_3       He took out cucumber  s13-d21          627        975
# 3  s13-d21_1_4          He took out plate  s13-d21         1004       1353
# 4  s13-d21_1_5         He washed cucumber  s13-d21         1366       1594
#
#                   Video_path  CaptionNums  exists
# 0  ./data/videos/s13-d21.avi          112    True
# 1  ./data/videos/s13-d21.avi          112    True
# 2  ./data/videos/s13-d21.avi          112    True
# 3  ./data/videos/s13-d21.avi          112    True
# 4  ./data/videos/s13-d21.avi          112    True

# %%
len(tacos_data[])

# %% [markdown]
# # Only select data described as str type

# %%
tacos_data.to_csv("tacos_linux.csv")

# %%
tacos_data=tacos_data[tacos_data['sentence'].apply(lambda x : isinstance(x,str))]

# %%
tacos_data = tacos_data[tacos_data['exists']==True]

# %% [markdown]
# # Get all descriptions

# %%
TrainCaptions=tacos_data['sentence'].values

# %%
len(TrainCaptions),TrainCaptions[:5]
# Out:
# (0, array([], dtype=object))

# %% [markdown]
# # Delete useless characters in the description

# %%
def replace_map(str_array):
    str_array=map(lambda x: x.replace('.',''),str_array)
    str_array=map(lambda x: x.replace('/',''),str_array)
    str_array=map(lambda x: x.replace('?',''),str_array)
    str_array=map(lambda x: x.replace(',',''),str_array)
    str_array=map(lambda x: x.replace(':',''),str_array)
    str_array=map(lambda x: x.replace('"',''),str_array)
    str_array=map(lambda x: x.replace('!',''),str_array)
    str_array=map(lambda x: x.replace('\\',''),str_array)
    str_array=map(lambda x: x.replace('\n',''),str_array)
    return str_array

# %%
#TrainCaptions=np.asarray(TrainCaptions,dtype=np.object)
str_array=replace_map(TrainCaptions)
str_array

# %%
next(str_array),next(str_array)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-24-732dafb8313e> in <module>
# ----> 1 next(str_array),next(str_array)
#
# StopIteration:

# %%
import cv2
import time

# %%
idx=np.random.randint(0,len(tacos_data))
video_id = tacos_data.iloc[idx,2]
path=tacos_data.iloc[idx,5]
caption=tacos_data.iloc[idx,1]
start = tacos_data.iloc[idx,3]
end = tacos_data.iloc[idx,4]
video_id,path,caption, start, end
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-ac5b7b5ce9b9> in <module>
# ----> 1 idx=np.random.randint(0,len(tacos_data))
#       2 video_id = tacos_data.iloc[idx,2]
#       3 path=tacos_data.iloc[idx,5]
#       4 caption=tacos_data.iloc[idx,1]
#       5 start = tacos_data.iloc[idx,3]
#
# mtrand.pyx in numpy.random.mtrand.RandomState.randint()
#
# _bounded_integers.pyx in numpy.random._bounded_integers._rand_int32()
#
# ValueError: low >= high

# %%
"""cap =cv2.VideoCapture(path)
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == True:
        frame=cv2.putText(frame,caption,(100,100),1,1.,(0,0,255))
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        cv2.imshow('frame',frame)
        if cv2.waitKey(25) & 0xFF == ord('q'): 
            break
    else:
        break
        
    
cap.release()
cv2.destroyAllWindows()"""
# Out:
# "cap =cv2.VideoCapture(path)\nwhile(cap.isOpened()):\n    ret, frame = cap.read()\n    if ret == True:\n        frame=cv2.putText(frame,caption,(100,100),1,1.,(0,0,255))\n        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)\n        cv2.imshow('frame',frame)\n        if cv2.waitKey(25) & 0xFF == ord('q'): \n            break\n    else:\n        break\n        \n    \ncap.release()\ncv2.destroyAllWindows()"

# %%
tacos_data.to_csv("tacos_server.csv")

# %%
def process_skip(path,video_id,start,end):
    current_frame = int(start)
    cap = cv2.VideoCapture(path)
    cap.set(cv2.CAP_PROP_POS_FRAMES, current_frame)
    fps = cap.get(cv2.CAP_PROP_FPS)
    fourcc = int(cap.get(cv2.CAP_PROP_FOURCC))
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    end_frame = int(end)
    out = cv2.VideoWriter(video_id+"_"+str(current_frame)+"_"+str(end_frame)+".avi", fourcc, fps, (w,h))
    frame_count = 0
    while frame_count < end_frame:
        ret, frame = cap.read()
        frame_count += 1
        if frame_count >= start_frame:
            out.write(frame)
    cap.release()
    out.release()

# %%
def process_video(path,video_id,start,end):
    start_frame = int(start)
    end_frame = int(end)

    cap = cv2.VideoCapture(path)
    cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
    fps = cap.get(cv2.CAP_PROP_FPS)
    fourcc = int(cap.get(cv2.CAP_PROP_FOURCC))
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    out = cv2.VideoWriter(video_id+"_"+str(start_frame)+"_"+str(end_frame)+".avi", fourcc, fps, (w,h))
    
    frame_count = 0
    while frame_count < end_frame:
        ret, frame = cap.read()
        frame_count += 1
        if frame_count >= start_frame:
            out.write(frame)
    cap.release()
    out.release()

# %%
def process_video_frame(path,video_id,start,end):
    start_frame = int(start)
    end_frame = int(end)
    frame_count = 0
    frame_list = []
    cap = cv2.VideoCapture(path)
    
    while frame_count < end_frame:
        ret, frame = cap.read()
        if ret is False:
            break
        frame_list.append(frame)
        frame_count += 1 
        if frame_count >= start_frame:
            break
    
    cap.release()
    return frame_list

# %%
def image_io(path,video_id,start,end):
    video_reader = imageio.get_reader(path)
    video_writer = imageio.get_writer(video_id+"_"+str(start)+"_"+str(end)+".avi", fps=30)
    n_frames = 0
    for frame in video_reader:
        n_frames += 1
        if (int(start)<n_frames<int(end)):
            video_writer.append_data(frame)
    video_writer.close()

# %%
def get_name(path,video_id,start,end):
    return path,video_id,start,

len(tacos_data)
# Out:
# 17932

# %%
def get_name(x):
    all_enty = []
    for idx in range(len(x)):
        video_id = x.iloc[idx,2]
        path=x.iloc[idx,5]
        caption=x.iloc[idx,1]
        start = x.iloc[idx,3]
        end = x.iloc[idx,4]
        all_enty.extend([[video_id,path,caption,start,end]])
    return all_enty

# %%
all_enteries = get_name(tacos_data)

# %%
all_enteries
# Out:
# [['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He took out cutting board',
#   252,
#   452],
#  ['s13-d21', '.\\data\\videos\\s13-d21.avi', 'He took out knife', 471, 627],
#  ['s13-d21', '.\\data\\videos\\s13-d21.avi', 'He took out cucumber', 627, 975],
#  ['s13-d21', '.\\data\\videos\\s13-d21.avi', 'He took out plate', 1004, 1353],
#  ['s13-d21', '.\\data\\videos\\s13-d21.avi', 'He washed cucumber', 1366, 1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'Cut off ends of cucumbers',
#   1665,
#   2036],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He sliced cucumbers',
#   2099,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He put cucumbers on plate',
#   2618,
#   2844],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'person takes chopping board out',
#   252,
#   452],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'person removes knife from draw',
#   471,
#   627],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'person removes cucumber out of refrigerator',
#   627,
#   975],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'person removes plate out of cabinet',
#   1004,
#   1353],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'person then washes cucumber',
#   1366,
#   1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'person then places cucumber on plate',
#   1665,
#   1813],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'perosn then cuts ends off cucumber',
#   1854,
#   2036],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'person then cuts cucumber in slices',
#   2099,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'person then places cucumber on plate.',
#   2618,
#   2717],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person gets out a cutting board.',
#   252,
#   452],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person gets out a knife.',
#   471,
#   627],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person gets out a cucumber.',
#   627,
#   975],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person gets out a plate.',
#   1004,
#   1353],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person rinses the cucumber.',
#   1366,
#   1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person cuts the tips off the cucumber.',
#   1665,
#   2036],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person slices the cucumber and puts the slices on the plate.',
#   2798,
#   2844],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person gets out a cutting board.',
#   252,
#   452],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person gets out a knife.',
#   471,
#   686],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person gets out a cucumber.',
#   723,
#   975],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person gets out a plate.',
#   1004,
#   1353],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person rinses the cucumber.',
#   1366,
#   1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person cuts off the tips  of the cucumber.',
#   1665,
#   2036],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person cuts up the cucumber.',
#   2099,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person puts the cucumber slices on the plate.',
#   2618,
#   2717],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person takes out a cutting board from the drawer.',
#   252,
#   452],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person takes out a knife from the drawer.',
#   471,
#   686],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person procures a cucumber from the fridge.',
#   723,
#   975],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person procures a plate from the cabinet.',
#   1004,
#   1353],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person washes the cucumber in the sink.',
#   1366,
#   1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person cuts the ends off the cucumber then cuts the body into slices.',
#   1665,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person sets cucumber slices on the plate.',
#   2618,
#   2717],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person takes out a cutting board from the drawer.',
#   252,
#   452],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person takes out a knife from the drawer.',
#   471,
#   627],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person procures a cucumber from the fridge then takes a plate from the cabinet.',
#   627,
#   1353],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person washes the cucumber in the sink.',
#   1366,
#   1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person cuts the ends from the cucumber.',
#   1665,
#   2036],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person chops the cucumber into slices on the cutting board.',
#   2099,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person sets the cucumber slices on the plate.',
#   2618,
#   2717],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person takes out a cutting board from the drawer.',
#   252,
#   452],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person takes out a knife from the drawer.',
#   471,
#   627],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person procures a cucumber from the fridge.',
#   627,
#   975],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person procures a plate from the cabinet.',
#   1004,
#   1353],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person washes the cucumber in the sink.',
#   1366,
#   1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person cuts the ends off the cucumber.',
#   1665,
#   2036],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person slices the cucumber on the cutting board.',
#   2099,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person sets the sliced cucumber on the plate.',
#   2618,
#   2717],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He goes to the drawer and takes out a cutting board and knife.',
#   252,
#   686],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He goes to the refrigerator and takes out a cucumber.',
#   723,
#   975],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He goes to the cupboard and takes out a plate and places it on the counter.',
#   1004,
#   1413],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He goes to the sink and washes the cucumber.',
#   1450,
#   1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He then cuts off the ends of the cucumber and then slices the cucumber.',
#   1665,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He picks up the cucumber and places it on the plate.',
#   2099,
#   2844],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He opens the drawers and takes out a cutting board and a knife.',
#   252,
#   686],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He gets a cucumber from the refrigerator and a plate from the cabinet.',
#   723,
#   1353],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He sets the plate down and washes the cucumber in the sink.',
#   1366,
#   1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He puts the cucumber on the plate and dries off his hands.',
#   1665,
#   1813],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He uses the knife to cut off the ends of the cucumbers.',
#   1854,
#   2036],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He uses the knife to slice the cucumber into smaller pieces.',
#   2099,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He picks up the pieces of cucumber and places them on the plate.',
#   2798,
#   2844],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person takes out a cutting board from the drawer.',
#   252,
#   452],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person takes out a knife from the drawer.',
#   471,
#   627],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person procures a cucumber from the fridge.',
#   627,
#   975],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person procures a plate from the cabinet.',
#   1004,
#   1353],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person washes the cucumber in the sink.',
#   1366,
#   1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person chops the ends off the cucumber on the cutting board.',
#   1665,
#   2036],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person slices the cucumber on the cutting board.',
#   2099,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   ' The person sets the sliced cucumber on the plate.',
#   2618,
#   2717],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He gets out the cutting board, knife, plate, and cucumber from drawers and the refrigerator.',
#   252,
#   1413],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He washes the cucumber in the sink and puts it on the plate.',
#   1450,
#   1721],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He wipes his hand on the rag.',
#   1750,
#   1883],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He chops the ends off the cucumber.',
#   1883,
#   2036],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He chops the cucumber into pieces with the knife.',
#   2099,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He gathers the chopped cucumbers together on a plate.',
#   2798,
#   2844],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'the man is opening the drawer',
#   252,
#   452],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'the man is placing a knife on the cutting board he got from the drawer',
#   471,
#   627],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'the man is opening the refridgerator',
#   627,
#   686],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'he got a cucumber from the refridgerator',
#   723,
#   975],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'the man is washing the cucumber',
#   1004,
#   1413],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'the man is slicing the cucumber width-wise',
#   1450,
#   2036],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'then the man arranges the cucumbers on a plate',
#   2798,
#   2844],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man places a cutting board on the counter.',
#   252,
#   452],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man places a knife on the cutting board.',
#   471,
#   627],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man gets a cucumber out of the refrigerator.',
#   627,
#   975],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man gets a plate out of the cupboard.',
#   1004,
#   1353],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man rinses the cucumber.',
#   1366,
#   1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man dries his hands.',
#   1665,
#   1813],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man cuts the ends off of the cucumber.',
#   1854,
#   2036],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man cuts the cucumber into slices.',
#   2099,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man arranges the cucumber slices on the plate.',
#   2798,
#   2844],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person takes a cutting board from the drawer.',
#   252,
#   452],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person removes a large knife from a drawer and puts it on the cutting board.',
#   471,
#   686],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person takes a cucumber from the fridge.',
#   723,
#   975],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person takes a plate from the cabinet.',
#   1004,
#   1353],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person washes the cucumber in the sink.',
#   1366,
#   1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person dries his hands with the towel.',
#   1665,
#   1813],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person slices the cucumber.',
#   1854,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The person places the sliced cucumber onto the plate.',
#   2618,
#   2717],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He places the cutting board on the counter',
#   252,
#   452],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He placed the knife on the cutting board',
#   471,
#   686],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'He got a cucumber from the refrigerator',
#   723,
#   975],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man washed the cucumber in the sink',
#   1004,
#   1594],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man dried his hands on the towel',
#   1665,
#   1813],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man cut the cucumber into slices',
#   1854,
#   2523],
#  ['s13-d21',
#   '.\\data\\videos\\s13-d21.avi',
#   'The man placed the cucumber slices on the plate',
#   2618,
#   2844],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person takes the loaf of bread out of the cupboard.',
#   237,
#   508],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets a plate out of the cupboard.',
#   578,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person unwraps the loaf of bread.',
#   904,
#   1330],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person takes out a bread knife from the drawer.',
#   1357,
#   1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'While holding the loaf with one hand, the person slices off the end of the loaf using the bread knife.',
#   1560,
#   1788],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person takes out a cutting board from the drawer, and puts the loaf (and piece of bread) onto it.',
#   1865,
#   2024],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person finishes his first cut, and slices a second piece of bread from the end of the loaf.',
#   2071,
#   2520],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person places the pieces of bread onto the plate.',
#   2591,
#   2702],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person puts the wrapping back onto the bread and picks it up.',
#   2715,
#   2899],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The boy gets out the bread and sets it on the counter.',
#   237,
#   508],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The boy gets out a plate and places it on the counter.',
#   578,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The boy takes the bread out of the package.',
#   904,
#   1330],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The boy takes the knife out of the drawer.',
#   1357,
#   1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The boy slices a piece of bread.',
#   1560,
#   1788],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The boy takes out the cutting board and places the bread on it.',
#   1865,
#   2024],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The boy slices two pieces of bread.',
#   2071,
#   2520],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The boy places the sliced bread on the plate.',
#   2591,
#   2672],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The boy puts the bread back into the package.',
#   2676,
#   2899],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person takes a loaf of bread from the pantry.',
#   237,
#   508],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person procures a plate from the cabinet.',
#   578,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person opens the package of bread.',
#   904,
#   1330],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person takes out a knife from the drawer.',
#   1357,
#   1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person takes out a cutting board from the drawer.',
#   1560,
#   1959],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person cuts two slices of bread from the loaf.',
#   1977,
#   2520],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person sets the slices of bread on the plate.',
#   2591,
#   2702],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a loaf of bread in plastic wrap.',
#   237,
#   508],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a plate.',
#   578,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person unwraps the bread.',
#   904,
#   1330],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a knife.',
#   1357,
#   1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person starts cutting the bread.',
#   1560,
#   1788],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a wooden plate.',
#   1865,
#   1959],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person puts the bread on the wooden plate.',
#   1977,
#   2024],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person cuts two slices of bread and puts them on the plate.',
#   2071,
#   2672],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person wraps the bread back up.',
#   2715,
#   2899],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person places a loaf of bread on the counter.',
#   237,
#   508],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person places a plate on the counter.',
#   578,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person opens the package of bread.',
#   904,
#   1330],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person takes a knife out of the drawer.',
#   1357,
#   1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person begins to slice the bread.',
#   1560,
#   1788],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person places the loaf of bread on a cutting board.',
#   1865,
#   2024],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person finishes slicing two pieces of bread from the loaf.',
#   2071,
#   2520],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person places the bread on the plate.',
#   2591,
#   2702],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   "The person reseals the bread's package.",
#   2676,
#   2899],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'Video ends.', 2676, 2899],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a loaf of bread in plastic wrap.',
#   237,
#   508],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a plate.',
#   578,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person unwraps the bread.',
#   904,
#   1330],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a knife.',
#   1357,
#   1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person starts to slice the bread.',
#   1560,
#   1788],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a wooden plate.',
#   1865,
#   1959],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person cuts off two slices of bread and puts them on the plate.',
#   1977,
#   2672],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person wraps the bread back up.',
#   2715,
#   2899],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He took out bread', 237, 508],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He took out plate', 578, 861],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He opened bread', 904, 1330],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He took out knife', 1357, 1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He took out cutting board',
#   1560,
#   1959],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He sliced bread', 1977, 2520],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He gets out a loaf of bread from the cabinet.',
#   237,
#   508],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He gets out a plate from the cabinet.',
#   578,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He removes the cover from the loaf of bread.',
#   904,
#   1330],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He gets out a knife and slices off a piece of bread from the loaf of bread.',
#   1357,
#   1788],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He gets a cutting board from the drawer and places the loaf of bread on top of it.',
#   1865,
#   2024],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He cuts the first slice further and cuts off another slice of bread.',
#   2071,
#   2520],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He picks up the pieces of bread and places them on the plate.',
#   2591,
#   2702],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He puts the cover back on the bread.',
#   2676,
#   2899],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'Take out a loaf of bread and a plate.',
#   237,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'Tear off the packaging to access the loaf.',
#   904,
#   1330],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'Take out a long serrated knife.',
#   1357,
#   1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'Take out a cutting board, put the bread on it and cut it into slices using a sawing motion with the knife.',
#   2591,
#   2622],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'Put the slices of bread on the plate and re-wrap the loaf.',
#   2715,
#   2899],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He took out bread', 237, 508],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He took out plate', 578, 861],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He took out knife', 904, 1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He took out cutting board',
#   1560,
#   1959],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He sliced bread', 1977, 2520],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He grabs a loaf of bread.',
#   237,
#   508],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He grabs a plate.', 578, 861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He opens the loaf of bread.',
#   904,
#   1330],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He gets a knife.', 1357, 1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He gets a cutting board and cuts two slices.',
#   1560,
#   2520],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He puts the slices on a plate.',
#   1560,
#   2702],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a loaf of bread in plastic wrap.',
#   237,
#   508],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a plate.',
#   578,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person unwraps the bread.',
#   904,
#   1330],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a knife.',
#   1357,
#   1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person starts to cut the bread.',
#   1560,
#   1788],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a wooden plate.',
#   1865,
#   1959],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person puts the bread on the wooden plate.',
#   1977,
#   2024],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person cuts off two slices of bread and puts them on the first plate.',
#   2591,
#   2672],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person wraps the rest of the bread back up.',
#   2646,
#   2899],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'Get out the loaf of bread.',
#   237,
#   508],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'Get out a serving dish.',
#   578,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'If needed, open plastic or paper covering bread.',
#   904,
#   1330],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'Get out a sharp bread knife.',
#   1357,
#   1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'Get out a cutting board.',
#   1560,
#   1959],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'Slice desired amount of bread into 1" thick slices.',
#   1977,
#   2520],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'Arrange sliced bread on dish.',
#   2591,
#   2702],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'Cover remaining bread with existing plastic/paper.',
#   2715,
#   2899],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He gets a loaf of bread out from the pantry and places it on the counter.',
#   237,
#   508],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He gets a plate out from the cupboard.',
#   578,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He opens the container of the loaf of bread.',
#   904,
#   1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He gets out a knife and makes a slice in the loaf of bread.',
#   1560,
#   1788],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He gets out a round cutting board and places the bread on top of it.',
#   1865,
#   2024],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   "He pushes the knife in deeper to the previous and cut and removes the bread's covering from that region.",
#   2071,
#   2206],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He finishes cutting two slices and he places them on the plate.',
#   2071,
#   2702],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He puts the cover over the bread.',
#   2676,
#   2899],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a loaf of bread in plastic wrap.',
#   237,
#   508],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a plate.',
#   578,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person unwraps the bread.',
#   904,
#   1330],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a knife.',
#   1357,
#   1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person starts cutting the bread.',
#   1560,
#   1788],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person gets out a wooden plate.',
#   1865,
#   1959],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person puts the bread on the wooden plate.',
#   1977,
#   2024],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person cuts two slices of bread and puts them on the first plate.',
#   2591,
#   2672],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person wraps the rest of the bread back up.',
#   2715,
#   2899],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person got a loaf of bread from the pantry.',
#   237,
#   508],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person got a plate from the cabinet.',
#   578,
#   861],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person opened the bread packaging.',
#   904,
#   1330],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person got a knife from the drawer.',
#   1357,
#   1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person got a cutting board from the drawer.',
#   1560,
#   1959],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person used the bread knife to cut two slices of bread from the loaf.',
#   2304,
#   2622],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person set the bread slices onto the plate.',
#   2646,
#   2702],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'The person rewrapped the loaf of bread in its package.',
#   2715,
#   2899],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He took out bread', 237, 508],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He took out plate', 578, 861],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He took out knife', 904, 1518],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He took out cutting board',
#   1560,
#   2024],
#  ['s13-d25', '.\\data\\videos\\s13-d25.avi', 'He sliced bread', 2071, 2520],
#  ['s13-d25',
#   '.\\data\\videos\\s13-d25.avi',
#   'He put bread on plate',
#   2071,
#   2702],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person got out a cutting board.',
#   266,
#   453],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person got out a knife.',
#   471,
#   700],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person got an orange out of the cupboard.',
#   746,
#   1245],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person got a plate.',
#   1338,
#   1597],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person rinsed the orange in the sink.',
#   1666,
#   1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person cut the ends off the orange.',
#   1902,
#   2248],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person peeled the orange.',
#   2271,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person cut the orange in slices.',
#   3127,
#   3635],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person cut each slice in quarters.',
#   3685,
#   4441],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person put the pieces of orange on the plate.',
#   4482,
#   5402],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person takes out a cutting board from the drawer.',
#   266,
#   453],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person takes out a knife from the drawer.',
#   471,
#   645],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person takes an orange from the pantry.',
#   645,
#   1245],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person procures a plate from the cabinet.',
#   1338,
#   1597],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person washes the orange in the sink.',
#   1666,
#   1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person peels the orange with the knife.',
#   1902,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person cuts the orange into slices, quarters the slices, then slides them onto the plate.',
#   3127,
#   5402],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man gets a cutting board and knife from the drawer, before walking over and getting an orange and plate out of two different cabinets.',
#   266,
#   1597],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man rinses the orange under the sink.',
#   1666,
#   1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man places the orange on the cutting board and uses the knife to slice off the ends.',
#   1902,
#   2248],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man takes the knife and digs it into the orange then begins to peel the orange by going around in a circle.',
#   2271,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man takes the orange and starts at one end and makes six slices.',
#   3127,
#   3461],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man takes the first slice and cuts it into fours.',
#   3465,
#   3835],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man takes the remaining five slices and cuts them into fours.',
#   3840,
#   4441],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man gently places the four halves of each slice onto the awaiting plate.',
#   4482,
#   5402],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He took out cutting board',
#   266,
#   453],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He took out knife', 471, 645],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He took out orange', 645, 1245],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He took out plate', 1338, 1597],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He washed orange', 1666, 1800],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He peeled orange', 1902, 2950],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He sliced orange', 3127, 3461],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He cut up slices', 3465, 4441],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He put orange on plate',
#   4482,
#   5402],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He gets a cutting board out of the cupboard.',
#   266,
#   453],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He gets a knife out of the drawer.',
#   471,
#   645],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   ' He gets an orange out of the cupboard.',
#   645,
#   1245],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He gets a plate out of the cupboard.',
#   1338,
#   1597],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He rinses the orange.',
#   1666,
#   1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He cuts the ends off the orange and uses the knife the peel the orange.',
#   1902,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He cuts the orange into slices.',
#   3127,
#   4441],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He puts the slices on the plate.',
#   4482,
#   5402],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man takes out a cutting board and a knife.',
#   266,
#   700],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man gets and orange and washes it.',
#   746,
#   1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man slices off the ends of the orange.',
#   1902,
#   2248],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man then peels the orange with a knife.',
#   2271,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man slices the orange and puts the pieces onto the plate.',
#   5459,
#   5516],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man removes a cutting board and knife from the drawers.',
#   266,
#   700],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He removes an orange and a plate from the cabinets.',
#   746,
#   1597],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He rinses the orange in the sink.',
#   1666,
#   1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He uses the knife to cut the ends off of the orange.',
#   1902,
#   2248],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He uses the knife to peel the skin off the orange in a circular fashion.',
#   2271,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He uses the knife to slice the orange.',
#   3127,
#   3635],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He cuts each slice of the orange into quarters.',
#   3685,
#   4441],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He transfers the orange pieces from the cutting board onto the plate.',
#   4482,
#   5402],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He gets a cutting board.',
#   266,
#   453],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He gets a knife.', 471, 645],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He gets an orange.', 645, 1245],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He rinses the orange.',
#   1338,
#   1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He peels the orange.',
#   1902,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He cuts up the orange and puts it on a plate.',
#   3127,
#   5402],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person takes out a cutting board from the drawer.',
#   266,
#   453],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person takes out a knife from the drawer.',
#   471,
#   645],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person takes an orange from the pantry.',
#   645,
#   1245],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person procures a plate from the cabinet.',
#   1338,
#   1597],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person washes the orange in the sink.',
#   1666,
#   1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person uses the knife to peel the orange.',
#   1902,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person cuts the peeled orange into slices.',
#   3127,
#   3635],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person cuts the slices in halves.',
#   3685,
#   4441],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person sets the oranges on the plate.',
#   4482,
#   5402],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He gets a cutting board and a knife from the drawers and an orange and a plate from the cupboard.',
#   266,
#   1597],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He washes the orange in the sink and places it on the cutting board.',
#   1666,
#   1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He dries his hands and uses his knife to cut off the ends of the orange.',
#   1902,
#   2248],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He uses the knife to remove the rest of the peel from the orange.',
#   2271,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He uses the knife to slice the orange into pieces.',
#   3127,
#   3461],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He slices each piece horizontally and vertically into pieces.',
#   3465,
#   4441],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He uses the knife and his hand to pick up all of the orange pieces and put them on the plate.',
#   5459,
#   5516],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'Get out a cutting board and knife.',
#   266,
#   645],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'Get out a clean plate.',
#   645,
#   1597],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'Rinse the orange in water.',
#   1666,
#   1800],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'Cut off the ends.', 1902, 2248],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'Use the knife to peel the orange by circling the orange.',
#   1902,
#   2248],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'Cut the orange by slicing the knife in a vertical manner.',
#   2271,
#   3461],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'Cut each piece into four parts.',
#   3465,
#   4005],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'Place orange slices onto plate.',
#   4005,
#   5103],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He took out cutting board',
#   266,
#   453],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He took out knife', 471, 700],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He took out orange', 746, 1245],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He took out plate', 1338, 1597],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He washed orange', 1666, 1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He cut off top of orange',
#   1902,
#   2248],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He peeled orange', 2271, 2950],
#  ['s13-d28', '.\\data\\videos\\s13-d28.avi', 'He sliced orange', 3127, 4579],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He put orange on plate',
#   5107,
#   5402],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person takes a chopping board out of the drawer.',
#   266,
#   453],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person takes a knife out of the drawer.',
#   471,
#   645],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person takes out an orange from the cupboard.',
#   645,
#   1245],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person takes out a plate from the cupboard.',
#   1338,
#   1597],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person washes the orange.',
#   1666,
#   1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person dries his hands with a towel.',
#   1902,
#   1975],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person peels the skin off the orange.',
#   2077,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The person cuts the peeled orange into small pieces and puts them on the plate.',
#   4779,
#   5402],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He removes the utensils from the drawer.',
#   266,
#   700],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He removes an orange and plate from the cabinets.',
#   746,
#   1597],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He washes the orange.',
#   1666,
#   1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He dries his hands on a towel.',
#   1902,
#   1975],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He slices the ends off of the orange.',
#   2077,
#   2248],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He peels the orange in a circular motion with a knife.',
#   2271,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He slices the orange in halves and quarters.',
#   3127,
#   4441],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He uses the knife to help lift the orange pieces to the plate.',
#   3127,
#   5402],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He is done preparing the orange and steps back from the counter.',
#   5459,
#   5516],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man enters the kitchen and removes a cutting board from the drawer.',
#   266,
#   453],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   ' The man than retrieves a knife from a different drawer.',
#   471,
#   700],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He walks over to the cabinet and takes out an orange and a plate and places them on the counter.',
#   746,
#   1597],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   ' The man washes the orange in the sink and places it on the cutting board.',
#   1666,
#   1800],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He begins preparing the orange by slicing the ends off.',
#   1902,
#   2248],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man peels the skin of the orange off with a knife by going in a circular motion.',
#   2271,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man thinly slices the orange.',
#   3127,
#   3635],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   ' The man then cuts the thinly sliced pieces into fours.',
#   3685,
#   4579],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man places the small pieces of the sliced orange onto a plate.',
#   4482,
#   5402],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   ' The man relocates the plate on the counter.',
#   5459,
#   5516],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man retrieves a cutting board, a knife, an orange, and a plate.',
#   266,
#   1597],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man rinses off the orange and dries his hands on a towel.',
#   1666,
#   1975],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'The man cuts both ends off of the orange.',
#   2077,
#   2248],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He peels the orange.',
#   2271,
#   2950],
#  ['s13-d28',
#   '.\\data\\videos\\s13-d28.avi',
#   'He cuts the orange into five pieces.',
#   3127,
#   3635],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He took out garlic press',
#   263,
#   584],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He took out plate', 584, 912],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He took out garlic', 949, 1289],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He took out knife', 1325, 1572],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He took out second plate',
#   1632,
#   1788],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He peeled garlic', 1887, 3384],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He pressed garlic', 3548, 4952],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Get your garlic press ready.',
#   263,
#   632],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'Grab a clean plate.', 676, 912],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Get your clove of garlic.',
#   949,
#   1289],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'Get a sharp knife.', 1325, 1572],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Grab a smaller clean plate.',
#   1632,
#   1788],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Beak your garlic clove apart, peeling each section and cutting off the ends.',
#   1887,
#   3384],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Place each section of garlic into the press and squeeze it over the larger plate.',
#   3548,
#   4478],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Grab a spoon and scrape off excess from press into plate.',
#   4530,
#   4952],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He gets out the utensils and the garlic.',
#   263,
#   1572],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He gets out a small plate.',
#   1632,
#   1788],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He removes one clove from the bunch.',
#   1887,
#   2205],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He presses the garlic.',
#   2218,
#   4478],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He removes the garlic from the press.',
#   4530,
#   4952],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'The man grabs a garlic press.',
#   263,
#   584],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'The man grabs a big plate.',
#   584,
#   912],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'The man grabs a bulb of garlic.',
#   949,
#   1289],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'The man grabs a knife.',
#   1325,
#   1519],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'The man grabs a smaller plate and places the bulb on it.',
#   1519,
#   1788],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'The man peels the skin off of 3 cloves.',
#   1887,
#   3384],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'The man presses the garlic and uses a spoon to get the extra off of the press.',
#   3548,
#   4952],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'The man completes his assigned task.',
#   3548,
#   4952],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He gets out the equipment and garlic.',
#   263,
#   1788],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He cuts open the bunch.',
#   1887,
#   2205],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He removes the skin from two cloves.',
#   2218,
#   3384],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He uses the press on the garlic.',
#   3548,
#   4478],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He cleans off the garlic press.',
#   4530,
#   4952],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He gets a garlic press.',
#   263,
#   584],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He gets a plate.', 584, 912],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He gets a bunch of garlic.',
#   949,
#   1289],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He sets a knife on the plate.',
#   1325,
#   1519],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He gets a few cloves from the bunch and removes their skin.',
#   1519,
#   3384],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He presses the garlic.',
#   3548,
#   4478],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He removes the garlic from the press.',
#   4530,
#   4902],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'The person removes a garlic press.',
#   263,
#   540],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'A plate is removed from a cabinet.',
#   540,
#   912],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'A bulb of garlic is removed from a cabinet.',
#   949,
#   1289],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'The person selects a knife.',
#   1325,
#   1519],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'A small plate is removed from a cabinet.',
#   1519,
#   1788],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Cloves are removed and peeled over the small plate.',
#   1887,
#   3384],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Cloves are placed in the press and pressed.',
#   3548,
#   4478],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'A spoon is used to remove garlic from the press.',
#   4530,
#   4902],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'The garlic is ready.',
#   4902,
#   4952],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Take out a garlic press, a plate, and a bulb of garlic.',
#   263,
#   1289],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Take out a small knife and a saucer.',
#   1325,
#   1788],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Use the knife to begin the separation, then use your hands to break apart the bulb.',
#   1887,
#   2205],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Use the knife to cut the ends off the selected garlic cloves.  Skin the cloves with the knife.',
#   2218,
#   3384],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Put the prepared cloves in the garlic press and press the garlic onto the plate.',
#   3548,
#   4478],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'Use a spoon to get any remaining garlic out of and off the garlic press.',
#   4902,
#   4952],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He took out press', 263, 584],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He took out plate', 584, 912],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He took out garlic', 949, 1289],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He took out knife', 1325, 1519],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He took out plate', 1519, 1788],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He peeled garlic', 1887, 3384],
#  ['s13-d31', '.\\data\\videos\\s13-d31.avi', 'He pressed garlic', 3548, 4624],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He gets a garlic press.',
#   263,
#   540],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He gets a plate and the garlic.',
#   540,
#   1289],
#  ['s13-d31',
#   '.\\data\\videos\\s13-d31.avi',
#   'He removes a few cloves and peels them.',
#   1325,
#   3384],
# ...
#   'The person procures a kiwi from a package in the fridge.',
#   689,
#   983],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person procures a plate from the cabinet.',
#   1015,
#   1358],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person washes the kiwi in the sink.',
#   1407,
#   1748],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person cuts the ends off the kiwi.',
#   1762,
#   2274],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person slices the kiwi on the cutting board and sets it on the plate.',
#   2274,
#   2612],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Person removes cutting board and knife',
#   230,
#   638],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'removes kiwi from the fridge and a plate from the cabinet',
#   689,
#   1358],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'Person washes kiwi', 1407, 1748],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Person dries his hands',
#   1762,
#   1977],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'Person slices kiwi', 2025, 2508],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'person arranges kiwi on a plate',
#   2519,
#   2612],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Person presents finished kiwi',
#   2025,
#   2723],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He opens the drawer', 230, 431],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'He takes out a cutting board',
#   230,
#   431],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He closes the drawer', 431, 497],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'He opens a different draw',
#   431,
#   497],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He takes out a knife', 502, 590],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'He opens the refrigerator',
#   590,
#   638],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He opens the cabinet', 689, 983],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'He takes out a plate',
#   1015,
#   1358],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'He turns on the sink',
#   1407,
#   1482],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'He washes the fruit',
#   1523,
#   1748],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He cuts the fruit', 1762, 2508],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'He serves the fruit',
#   2655,
#   2723],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'How to prepare a kiwi fruit.',
#   230,
#   431],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person takes out a cutting board.',
#   431,
#   497],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person takes out a knife.',
#   502,
#   638],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person takes out some fresh kiwi.',
#   689,
#   872],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person sets out a serving plate.',
#   900,
#   1358],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person selects one kiwi.',
#   1407,
#   1482],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person washes the kiwi.',
#   1523,
#   1748],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person places the clean kiwi on the cutting board.',
#   1762,
#   1827],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person cuts of both ends of the kiwi.',
#   1866,
#   2274],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person slices the kiwi.',
#   2274,
#   2508],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person takes the sliced kiwi and places them on the serving plate.',
#   2519,
#   2612],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person places a wood cutting board on the counter.',
#   230,
#   431],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person takes out a knife.',
#   431,
#   638],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person takes the kiwi out of the fridge.',
#   689,
#   872],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person takes out a clean plate.',
#   900,
#   1358],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person washes the kiwi.',
#   1407,
#   1748],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person dries his hands off.',
#   1762,
#   1977],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person slices the kiwi into thin pieces',
#   2025,
#   2508],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'The person places the cut kiwi on the clean plate.',
#   2025,
#   2723],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'First, reach into your kitchen drawer to take out a round cutting board.',
#   230,
#   497],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Then, continue to take out a small to medium sized knife.',
#   502,
#   638],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Bring out the kiwifruit from the refrigerator.',
#   689,
#   872],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   ' Then, take out a small white plate to serve.',
#   900,
#   1358],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'As the final step, wash the kiwifruit, dry your hands, and then slice into thin slices to serve on your plate.',
#   1787,
#   2723],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'He took out cutting board',
#   230,
#   431],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He took out knife', 431, 590],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He took out kiwi', 590, 872],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He took out plate', 900, 1358],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He washed kiwi', 1407, 1827],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He sliced kiwi', 1866, 2508],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'He put kiwi on plate',
#   2655,
#   2723],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Get out a cutting board.',
#   230,
#   431],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Get out a sharp knife.',
#   431,
#   590],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Get kiwi package out of fridge and open package.',
#   590,
#   983],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Get out a serving dish.',
#   1015,
#   1358],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Take one kiwi out of package.',
#   1407,
#   1482],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Wash the kiwi thoroughly under running water and shake off excess water.',
#   1523,
#   1787],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Dry hands off if needed.',
#   1787,
#   1977],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Cut off the end pieces of the kiwi.',
#   2025,
#   2274],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Slice the kiwi widthwise.',
#   2274,
#   2508],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Arrange kiwi on serving dish.',
#   2519,
#   2612],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Get your knife and cutting board ready.',
#   230,
#   638],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Get your Kiwi that you wish to prepare.',
#   689,
#   983],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Get the serving dish ready.',
#   1015,
#   1358],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Rinse the Kiwi thoroughly.',
#   1407,
#   1827],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Dry your hands after placing Kiwi on cutting board.',
#   1866,
#   1977],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Slice the ends from the Kiwi and discard.',
#   2025,
#   2274],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'Slice the Kiwi in several pieces and plate to serve.',
#   2655,
#   2723],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'He took out cutting board',
#   230,
#   431],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He took out knife', 431, 638],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He took out kiwi', 689, 872],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He took out plate', 900, 1358],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He washed kiwi', 1407, 1748],
#  ['s13-d52', '.\\data\\videos\\s13-d52.avi', 'He sliced kiwi', 1762, 2508],
#  ['s13-d52',
#   '.\\data\\videos\\s13-d52.avi',
#   'He put kiwi on plate',
#   2519,
#   2612],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He took out cutting board',
#   264,
#   404],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He took out plate and bowl',
#   404,
#   955],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He took out mango', 982, 1737],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He took out peeler', 1754, 2248],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He peeled mango', 2309, 3428],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He took out knife', 3439, 3574],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He sliced mango', 3590, 7245],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He put mango on plate',
#   7334,
#   8124],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The man gets a cutting board out.',
#   264,
#   513],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The man pulls out a plate, a bowl, and a mango.',
#   553,
#   1815],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He pulls out a peeler from the drawer.',
#   1841,
#   2248],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The man peels the mango.',
#   2309,
#   4159],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The man slices the mango with the knife.',
#   4189,
#   7245],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The man plates the mango.',
#   7334,
#   8124],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He took out cutting board',
#   264,
#   404],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He took out plate and bowl',
#   404,
#   955],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He took out mango', 982, 1600],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He took out peeler', 1630, 2248],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He peeled mango', 2309, 3428],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He took out knife', 3439, 3574],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He washed hands', 3590, 3683],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He sliced mango', 3698, 8124],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The man takes out a cutting board.',
#   264,
#   486],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He takes out a plate and a bowl.',
#   489,
#   955],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The man gets a mango from the refrigerator.',
#   982,
#   1815],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The man peels the mango.',
#   1841,
#   3428],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The man slices it into smaller pieces discarding unwanted parts.',
#   3439,
#   7080],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The man places it onto the plate ready for use.',
#   7177,
#   8124],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The person removes a cutting board.',
#   264,
#   404],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'A plate and bowl are removed for the mango.',
#   404,
#   955],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'A mango is removed from the refrigerator.',
#   982,
#   1549],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The person selects a peeler.',
#   1569,
#   2248],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The mango is peeled over the bowl.',
#   2309,
#   3428],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The person selects a knife.',
#   3439,
#   3554],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The person rinsed and dried their hands.',
#   3554,
#   3804],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The mango is placed on the cutting board and the ends are trimmed.',
#   3868,
#   4159],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The mango is sliced away from the seed.',
#   4189,
#   6168],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The slices are sliced smaller.',
#   6217,
#   7080],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The slices are placed on the plate.',
#   7177,
#   8033],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The mango is prepared.',
#   8097,
#   8124],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The man begins by setting a wooden cutting board on the counter.',
#   264,
#   513],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He then retrieves a plate and a bowl from the cupboard.',
#   553,
#   955],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'Next, he selects a mango from the fridge.',
#   982,
#   1815],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He uses a peeler to peel the skin off of the mango and then places the waste into a bowl.',
#   1841,
#   3428],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'Next, he uses a large knife to cut slices of the mango ultimately discarding the core into the bowl.',
#   3439,
#   6168],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'Finally, he cuts the mango into thinner slices and then displays them onto a plate.',
#   6217,
#   8033],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He gets a cutting board, a plate, and a bowl.',
#   264,
#   955],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He puts a mango on the cutting board.',
#   982,
#   1815],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He gets a knife.', 1841, 1970],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He peels the mango.',
#   1970,
#   3428],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He cuts the mango and puts it on a plate.',
#   8097,
#   8124],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He took out cutting board',
#   264,
#   404],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He took out plate and bowl',
#   404,
#   955],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He took out mango', 982, 1549],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He took out peeler', 1569, 2248],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He peeled mango', 2309, 3428],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He took out knife', 3439, 3574],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He washed hands', 3590, 3683],
#  ['s13-d54', '.\\data\\videos\\s13-d54.avi', 'He sliced mango', 3698, 6168],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He prepares a cutting board, bowl, plate, and peeler, and selects a mango.',
#   264,
#   2248],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He peels the mango, collecting the scraps in the bowl.',
#   2309,
#   3428],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'Using a knife, he removes inedible parts of the mango, discarding them into the bowl.',
#   3439,
#   4159],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He cuts the mango around the bone.',
#   4189,
#   4685],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He slices the edible parts of the mango off of the bone.',
#   6217,
#   6406],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He cuts the mango pieces into similar-sized strips.',
#   6457,
#   7399],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He places the prepared mango onto a plate and discards the rest.',
#   3439,
#   8124],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'The man begins by selecting a wooden cutting board and places it on the counter.',
#   264,
#   513],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He then retrieves a bowl and a plate from the cupboard.',
#   553,
#   955],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'Next, he selects a mango from the fridge and places it on the cutting board.',
#   982,
#   1815],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'Next, he takes out a peeler and peels the skin of the mango placing the skin into the bowl.',
#   1841,
#   3683],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'Using the knife, he trims the ends of the mango.',
#   3698,
#   4685],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'Next, he slices pieces of the mango off the core and then places the core into the discard bowl.',
#   4685,
#   6168],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He slices the mango pieces into thinner slices.',
#   4685,
#   7245],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'Finally, he places the finished slices onto the plate.',
#   7334,
#   7976],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He took out cutting board',
#   264,
#   404],
#  ['s13-d54',
#   '.\\data\\videos\\s13-d54.avi',
#   'He took out plate and bowl',
#   404,
#   955],
#  ...]

# %%
all_enteries_np = np.asarray(all_enteries)

len(all_enteries)
# Out:
# 17932

# %%
for i in range(len(all_enteries)):
    process_video(all_enteries[i][1],all_enteries[i][0],all_enteries[i][3],all_enteries[i][4])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-e54d2a8354b8> in <module>
#       1 for i in range(len(all_enteries)):
# ----> 2     process_video(all_enteries[i][1],all_enteries[i][0],all_enteries[i][3],all_enteries[i][4])
#       3
#
# <ipython-input-39-36a4d76161e8> in process_video(path, video_id, start, end)
#      14     frame_count = 0
#      15     while frame_count < end_frame:
# ---> 16         ret, frame = cap.read()
#      17         frame_count += 1
#      18         if frame_count >= start_frame:
#
# KeyboardInterrupt:

# %%
print(frames_all)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Out:
#   File "<ipython-input-108-fe6977ebcbfc>", line 1
#     for num in a_random(0:10):
#                          ^
# SyntaxError: invalid syntax
